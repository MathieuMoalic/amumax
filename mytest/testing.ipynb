# %%
# %matplotlib widget
# %load_ext autoreload
# %autoreload 2
from adl import adl,parms
from llyr import *
from matplotlib import pyplot as plt
import matplotlib.animation as mplanim
import matplotlib as mpl
import numpy as np
import cmocean
from glob import glob
from tqdm.notebook import tqdm
import matplotx
plt.style.use(matplotx.styles.dracula)
fix_bg()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# <style> .cell-output-ipywidget-background {background-color: transparent !important;}</style>

# %%
m = op("chunky.zarr")
m.p
# m.plot.snapshot()
# m.m.info
# m.p
plt.figure()
plt.imshow(m.Msat[-1,0,:,:,0],origin="lower")
# plt.plot(m.B_ext[:,0,0,0,1])
# Out:
# /
#  ├── Msat (1, 1, 1, 8192, 1) float32
#  └── m (1, 1, 1, 8192, 3) float32
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.figure()
arr = m.m1[1] - m.m2[1]
print(arr.max())
plt.imshow(arr[0,:,:,1])
# Out:
# 0.0
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
